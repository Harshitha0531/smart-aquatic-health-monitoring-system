# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-9b1e54fd-7111-43e7-9b4d-9bab9ca027ef" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9b1e54fd-7111-43e7-9b4d-9bab9ca027ef">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-34d1cb07-46b8-4f0c-9022-92c23e4fbd49" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-34d1cb07-46b8-4f0c-9022-92c23e4fbd49">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip resized_images_512.zip -d /content/resized_folder
# Out:
# Archive:  resized_images_512.zip
#   inflating: /content/resized_folder/resized_DSC_8910.jpg
#   inflating: /content/resized_folder/resized_DSC_8893.jpg
#   inflating: /content/resized_folder/resized_DSC_8894.jpg
#   inflating: /content/resized_folder/resized_DSC_8973.jpg
#   inflating: /content/resized_folder/resized_DSC_8895.jpg
#   inflating: /content/resized_folder/resized_DSC_8963.jpg
#   inflating: /content/resized_folder/resized_DSC_8942.jpg
#   inflating: /content/resized_folder/resized_DSC_8855.jpg
#   inflating: /content/resized_folder/resized_DSC_8846.jpg
#   inflating: /content/resized_folder/resized_DSC_8926.jpg
#   inflating: /content/resized_folder/resized_DSC_8931.jpg
#   inflating: /content/resized_folder/resized_DSC_8870.jpg
#   inflating: /content/resized_folder/resized_DSC_8900.jpg
#   inflating: /content/resized_folder/resized_DSC_8968.jpg
#   inflating: /content/resized_folder/resized_DSC_8951.jpg
#   inflating: /content/resized_folder/resized_DSC_8861.jpg
# ...

# %%
import pandas as pd
final_df=pd.read_csv('final_df.csv')

# %%
import tensorflow as tf
from tensorflow.keras.applications import VGG19
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam

# Load the pre-trained VGG19 model without the top layers
base_model = VGG19(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze the layers of VGG19 to retain pre-trained weights
for layer in base_model.layers:
    layer.trainable = False

# Add custom layers for regression
x = base_model.output
x = Flatten()(x)  # Flatten the output of the conv layers
x = Dense(512, activation='relu')(x)
x = Dropout(0.5)(x)  # Optional: Add dropout for regularization
x = Dense(256, activation='relu')(x)
x = Dropout(0.3)(x)
x = Dense(128, activation='relu')(x)
# Final output layer for regression (predicting dissolved oxygen value)
output = Dense(1, activation='linear')(x)

# Create the final model
model = Model(inputs=base_model.input, outputs=output)

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001), loss='mean_squared_error', metrics=['mae'])

# Summary of the model architecture
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 224, 224, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 224, 224, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 112, 112, 64)        │               0 │
# ...

# %%
import pandas as pd
import numpy as np
import cv2
from sklearn.model_selection import train_test_split

# Load the CSV file that contains image paths and dissolved oxygen values
final_df = pd.read_csv('final_df.csv')  # Update with your actual CSV file path

# Extract image paths and labels (dissolved oxygen values)
image_paths = final_df['img_path'].values  # Column containing image paths
dissolved_oxygen_values = final_df['DO_label_code'].values  # Column containing dissolved oxygen

# Define a function to load and preprocess images
def load_and_preprocess_image(image_path):
    image = cv2.imread(image_path)
    image = cv2.resize(image, (224, 224))  # Resize to 224x224
    image = image / 255.0  # Normalize to [0, 1] range
    return image

# Load all images
images = np.array([load_and_preprocess_image(img_path) for img_path in image_paths])

# Split the dataset into training and validation sets
train_images, val_images, train_labels, val_labels = train_test_split(
    images, dissolved_oxygen_values, test_size=0.2, random_state=42
)

# Train the model
history = model.fit(train_images, train_labels,
                    validation_data=(val_images, val_labels),
                    epochs=10,
                    batch_size=32)
# Out:
# Epoch 1/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 400s 31s/step - loss: 5.2518 - mae: 1.8509 - val_loss: 0.8043 - val_mae: 0.7533
# Epoch 2/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 403s 31s/step - loss: 1.6433 - mae: 1.0363 - val_loss: 0.8369 - val_mae: 0.7922
# Epoch 3/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 431s 30s/step - loss: 1.4816 - mae: 0.9940 - val_loss: 0.6968 - val_mae: 0.6933
# Epoch 4/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 446s 31s/step - loss: 1.3490 - mae: 0.9183 - val_loss: 0.6663 - val_mae: 0.6802
# Epoch 5/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 434s 30s/step - loss: 1.1834 - mae: 0.8869 - val_loss: 0.6771 - val_mae: 0.6902
# Epoch 6/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 443s 30s/step - loss: 1.3371 - mae: 0.9347 - val_loss: 0.7022 - val_mae: 0.7014
# Epoch 7/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 445s 31s/step - loss: 1.3040 - mae: 0.9052 - val_loss: 0.9061 - val_mae: 0.7751
# Epoch 8/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 395s 31s/step - loss: 1.1818 - mae: 0.9090 - val_loss: 0.9801 - val_mae: 0.7854
# Epoch 9/10
# ...
